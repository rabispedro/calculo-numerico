# %% [markdown]
# # Trabalho 22
#
# Crie um programa no Python para resolver o problema de valor inicial
#
# $$
# \dfrac{dy}{dt} = y \cdot t^3 - 1.5 \cdot y, \space y(0) = 1
# $$
#
# usando o método de Heun com iteração. O algoritmo deverá convergir para um erro tolerado para cada estimativa. Escolha $h = 0.25$, use 5 iterações e trabalhe com intervalo para $t$ de 0 a 1.

# %%
# Bibliotecas utilizadas

import matplotlib.pyplot as plt
import numpy as np

# %%
h = 0.25
steps = 5
x = np.linspace(0, 1, steps)

y = np.zeros(steps)
y[0] = 1

print(x, y)

phi = lambda x, y : y * (x ** 3) - 1.5 * y

for i in range(len(x) - 1):
	preditora = y[i] + phi(x[i], y[i]) * h
	y[i+1] = y[i] + (h/2) * (phi(x[i], y[i]) + phi(x[i+1],preditora))

print(f"Heun: {y}")

plt.plot(x, y, color='blue', marker='o', label="Heun com iteracao")

plt.title("Derivada por Euller")
plt.xlabel("x")
plt.ylabel("f'(x)")
plt.legend()

plt.show()
# Out:
# [0.   0.25 0.5  0.75 1.  ] [1. 0. 0. 0. 0.]
# Heun: [1.         0.6965332  0.4920031  0.36392734 0.2982676 ]
